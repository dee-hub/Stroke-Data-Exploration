# %%
import pandas as pd
df = pd.read_sas("LLCP2016.XPT", format='xport')

# %%
df
# Out:
#         _STATE  FMONTH        IDATE IMONTH   IDAY    IYEAR  DISPCODE  \
# 0          1.0     1.0  b'01072016'  b'01'  b'07'  b'2016'    1100.0
# 1          1.0     1.0  b'01112016'  b'01'  b'11'  b'2016'    1100.0
# 2          1.0     1.0  b'01062016'  b'01'  b'06'  b'2016'    1100.0
# 3          1.0     1.0  b'01082016'  b'01'  b'08'  b'2016'    1100.0
# 4          1.0     1.0  b'01052016'  b'01'  b'05'  b'2016'    1100.0
# ...        ...     ...          ...    ...    ...      ...       ...
# 486298    78.0    12.0  b'12312016'  b'12'  b'31'  b'2016'    1200.0
# 486299    78.0    12.0  b'12192016'  b'12'  b'19'  b'2016'    1100.0
# 486300    78.0    12.0  b'12092016'  b'12'  b'09'  b'2016'    1100.0
# 486301    78.0    12.0  b'12312016'  b'12'  b'31'  b'2016'    1200.0
# 486302    78.0    12.0  b'12312016'  b'12'  b'31'  b'2016'    1200.0
#
#                 SEQNO          _PSU  CTELENM1  ...  _MAM5021  _RFPAP33  \
# ...

# %%
df.to_csv("LLCP2016.csv", index=False)
